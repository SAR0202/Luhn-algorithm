# %%
# codigo final
tarjeta_num= (input(f'introduzca su numero de tarjeta de credito: ')).strip()
tarjeta_num = list(tarjeta_num)
tarjeta_num=[int(i) for i in tarjeta_num] #ayuda de chadgpt

#--------------logaritmo de luhn---------------
#declaro variasuma_paresles a usar
indice=0
suma_pares=0
suma_impares=0
suma_pares=0
resultado_final=0
#codigo
lista_2=tarjeta_num[1::2]
for i in lista_2:
    lista_2[indice]=i*2
    indice+=1
lista_2=[int(i) for i in lista_2]
for i in lista_2:
    if i>10 :
        a=i-10
        suma_impares+= 1 + a
    if i<10 :
        a=i
        suma_impares+= a
    if i==10 :
        a=1
        suma_impares+= 1


for i in tarjeta_num[0::2]:
    suma_pares+=i
resultado_final=suma_impares + suma_pares
#-------DECISION Y OUTPUT--------------------------------

if resultado_final % 10 ==0 or resultado_final==0:#verifico que sea valida o no la tarjeta
 #verifico de que compañia es la tarjeta
    if len(tarjeta_num)==15 and( (tarjeta_num[0]==3 and tarjeta_num[1]==4) or (tarjeta_num[0]==3 and tarjeta_num[1]==7)):
          print(f'su tarjeta es de AMERICAN EXPRESS')

    elif (len(tarjeta_num)==16 or len(tarjeta_num)==13) and tarjeta_num[0]== 4:
      print(f'su tarjeta es de VISA')

    elif len(tarjeta_num)==15 and(
          (tarjeta_num[0]==5 and tarjeta_num[1]==1 ) or
          (tarjeta_num[0]==5 and tarjeta_num[1]==2) or
          (tarjeta_num[0]==5 and tarjeta_num[1]==3) or
          (tarjeta_num[0]==5 and tarjeta_num[1]==4) or
          (tarjeta_num[0]==5 and tarjeta_num[1]==5)):
      print(f'su tarjeta es de MASTERCARD')
    else:
      print(f'no se reconoce la Empresa')
else:
  print(f'el numero de tarjeta ingresado no es valido')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # codigo final
# ----> 2 tarjeta_num= (input(f'introduzca su numero de tarjeta de credito: ')).strip()
#       3 tarjeta_num = list(tarjeta_num)
#       4 tarjeta_num=[int(i) for i in tarjeta_num] #ayuda de chadgpt
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# ...
